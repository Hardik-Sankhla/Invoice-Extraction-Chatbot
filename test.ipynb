# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.1-70b-versatile"
)

response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# e:\MLOPS\CondaEnvPy312\Lib\site-packages\langchain_groq\__init__.py:1: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   from langchain_groq.chat_models import ChatGroq
# e:\MLOPS\CondaEnvPy312\Lib\site-packages\pydantic\_internal\_config.py:341: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'populate_by_name'
#   warnings.warn(message, UserWarning)
# ...

# %%
export API_Key=AIzaSyAvFoWvp-JmXrXfsVInGkAOvGOBRVAtqrQ
# Out:
#   Cell In[13], line 1
#     export API_Key="AIzaSyAvFoWvp-JmXrXfsVInGkAOvGOBRVAtqrQ"
#            ^
# SyntaxError: invalid syntax

# %%
import google.generativeai as genai
import os
import config

API_Key="AIzaSyAvFoWvp-JmXrXfsVInGkAOvGOBRVAtqrQ"
genai.configure(api_key="AIzaSyAvFoWvp-JmXrXfsVInGkAOvGOBRVAtqrQ")

genai.configure(api_key=os.environ["API_Key"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 8
#       5 API_Key="AIzaSyAvFoWvp-JmXrXfsVInGkAOvGOBRVAtqrQ"
#       6 genai.configure(api_key="AIzaSyAvFoWvp-JmXrXfsVInGkAOvGOBRVAtqrQ")
# ----> 8 genai.configure(api_key=os.environ["API_Key"])
#
# File <frozen os>:714, in __getitem__(self, key)
#
# KeyError: 'API_Key'

# %%
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content("Write a story about a magic backpack.")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# Cell In[25], line 2
#       1 model = genai.GenerativeModel("gemini-1.5-flash")
# ----> 2 response = model.generate_content("Write a story about a magic backpack.")
#       3 print(response.text)
#
# File e:\MLOPS\CondaEnvPy312\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
# ...

# %%
curl \
  -H 'Content-Type: application/json' \
  -d '{"contents":[{"parts":[{"text":"Explain how AI works"}]}]}' \
  -X POST 'https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash-latest:generateContent?key=AIzaSyDe7oVAkpUD3DPUBEysqPyw8Vuh-wUuZmk'
# Out:
#   Cell In[26], line 2
#     -H 'Content-Type: application/json' \
#        ^
# SyntaxError: invalid syntax

# %%
# !pip uninstall google-generativeai

# %%
# !pip install -q -U google-generativeai
